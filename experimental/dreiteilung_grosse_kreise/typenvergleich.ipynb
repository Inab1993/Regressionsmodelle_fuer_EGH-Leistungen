# %%
import pandas as pd

# %%
df_dichte = pd.read_csv("../../data/processed/bevoelkerungsdichte_2024.csv")
df_typen = pd.read_csv("typen.csv")

df = df_dichte.merge(df_typen, how="left", on="Name")

print(df)
# Out:
#                           Name  Bevölkerungsdichte             Typ 1  \
# 0                   Düsseldorf              2845.7  Kreisfreie Stadt
# 1                     Duisburg              2157.1  Kreisfreie Stadt
# 2                        Essen              2732.2  Kreisfreie Stadt
# 3                      Krefeld              1679.5  Kreisfreie Stadt
# 4              Mönchengladbach              1567.5  Kreisfreie Stadt
# 5          Mülheim an der Ruhr              1895.8  Kreisfreie Stadt
# 6                   Oberhausen              2771.4  Kreisfreie Stadt
# 7                    Remscheid              1527.5  Kreisfreie Stadt
# 8                     Solingen              1849.7  Kreisfreie Stadt
# 9                    Wuppertal              2127.2  Kreisfreie Stadt
# 10                       Kleve               261.2     Kleiner Kreis
# 11                    Mettmann              1205.5      Großer Kreis
# 12           Rhein-Kreis Neuss               792.9      Großer Kreis
# 13                     Viersen               528.8      Großer Kreis
# 14                       Wesel               439.1      Großer Kreis
# 15                        Bonn              2292.2  Kreisfreie Stadt
# 16                        Köln              2529.8  Kreisfreie Stadt
# 17                  Leverkusen              2137.5  Kreisfreie Stadt
# 18                      Aachen               823.9      Städteregion
# 19                       Düren               296.6      Großer Kreis
# 20            Rhein-Erft-Kreis               678.3      Großer Kreis
# 21                  Euskirchen               162.3     Kleiner Kreis
# 22                   Heinsberg               419.9     Kleiner Kreis
# 23        Oberbergischer Kreis               298.3     Kleiner Kreis
# 24  Rheinisch-Bergischer Kreis               650.0      Großer Kreis
# 25            Rhein-Sieg-Kreis               525.0      Großer Kreis
# 26                     Bottrop              1178.2  Kreisfreie Stadt
# 27               Gelsenkirchen              2553.2  Kreisfreie Stadt
# 28                     Münster              1016.4  Kreisfreie Stadt
# 29                      Borken               268.0      Großer Kreis
# 30                    Coesfeld               204.9     Kleiner Kreis
# 31              Recklinghausen               816.1      Großer Kreis
# 32                   Steinfurt               251.5      Großer Kreis
# 33                   Warendorf               214.2     Kleiner Kreis
# 34                   Bielefeld              1281.2  Kreisfreie Stadt
# 35                   Gütersloh               375.5      Großer Kreis
# 36                     Herford               564.8      Großer Kreis
# 37                      Höxter               115.9     Kleiner Kreis
# 38                       Lippe               278.6      Großer Kreis
# 39             Minden-Lübbecke               278.2      Großer Kreis
# 40                   Paderborn               253.4      Großer Kreis
# 41                      Bochum              2462.4  Kreisfreie Stadt
# 42                    Dortmund              2149.8  Kreisfreie Stadt
# 43                       Hagen              1186.6  Kreisfreie Stadt
# 44                        Hamm               794.8  Kreisfreie Stadt
# 45                       Herne              3030.9  Kreisfreie Stadt
# 46           Ennepe-Ruhr-Kreis               766.9      Großer Kreis
# 47          Hochsauerlandkreis               133.1      Großer Kreis
# 48            Märkischer Kreis               384.6      Großer Kreis
# 49                        Olpe               185.9     Kleiner Kreis
# 50         Siegen-Wittgenstein               241.9      Großer Kreis
# 51                       Soest               226.0      Großer Kreis
# 52                        Unna               724.9      Großer Kreis
#
#                Typ 2
# 0   Kreisfreie Stadt
# 1   Kreisfreie Stadt
# 2   Kreisfreie Stadt
# 3   Kreisfreie Stadt
# 4   Kreisfreie Stadt
# 5   Kreisfreie Stadt
# 6   Kreisfreie Stadt
# 7   Kreisfreie Stadt
# 8   Kreisfreie Stadt
# 9   Kreisfreie Stadt
# 10             Kreis
# 11             Kreis
# 12             Kreis
# 13             Kreis
# 14             Kreis
# 15  Kreisfreie Stadt
# 16  Kreisfreie Stadt
# 17  Kreisfreie Stadt
# 18      Städteregion
# 19             Kreis
# 20             Kreis
# 21             Kreis
# 22             Kreis
# 23             Kreis
# 24             Kreis
# 25             Kreis
# 26  Kreisfreie Stadt
# 27  Kreisfreie Stadt
# 28  Kreisfreie Stadt
# 29             Kreis
# 30             Kreis
# 31             Kreis
# 32             Kreis
# 33             Kreis
# 34  Kreisfreie Stadt
# 35             Kreis
# 36             Kreis
# 37             Kreis
# 38             Kreis
# 39             Kreis
# 40             Kreis
# 41  Kreisfreie Stadt
# 42  Kreisfreie Stadt
# 43  Kreisfreie Stadt
# 44  Kreisfreie Stadt
# 45  Kreisfreie Stadt
# 46             Kreis
# 47             Kreis
# 48             Kreis
# 49             Kreis
# 50             Kreis
# 51             Kreis
# 52             Kreis

# %%
df.groupby("Typ 1")["Bevölkerungsdichte"].describe()
# Out:
#                   count         mean         std    min      25%      50%  \
# Typ 1
# Großer Kreis       22.0   485.440909  265.952251  133.1   270.55   411.85
# Kleiner Kreis       8.0   232.825000   94.160240  115.9   180.00   209.55
# Kreisfreie Stadt   22.0  1989.390909  643.461105  794.8  1537.50  2132.35
# Städteregion        1.0   823.900000         NaN  823.9   823.90   823.90
#
#                        75%     max
# Typ 1
# Großer Kreis       671.225  1205.5
# Kleiner Kreis      270.475   419.9
# Kreisfreie Stadt  2512.950  3030.9
# Städteregion       823.900   823.9

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df, x="Typ 1", y="Bevölkerungsdichte")
plt.show()

# %%
# Kruskal (nicht-parametrisch, da nicht normalverteilt)
from scipy.stats import kruskal

groups = [
    df.loc[df["Typ 1"] == t, "Bevölkerungsdichte"]
    for t in df["Typ 1"].unique()
]

median_diff_test = kruskal(*groups)

print(median_diff_test)
# Out:
# KruskalResult(statistic=np.float64(40.14174766533256), pvalue=np.float64(9.942816499507016e-09))

# %%
# einfaktorielle Anova
H = median_diff_test[0]
k = df["Typ 1"].nunique()
n = len(df)


eta_squared = (H - k + 1) / (n - k)
print(eta_squared)
# Out:
# 0.7579948503129094

# %%
aachen = df.loc[df["Name"] == "Aachen", "Bevölkerungsdichte"].iloc[0]
summary = df.groupby("Typ 1")["Bevölkerungsdichte"].median()

dist_to_city = abs(aachen - summary["Kreisfreie Stadt"])
dist_to_large = abs(aachen - summary["Großer Kreis"])

print(dist_to_city, dist_to_large)
# Out:
# 1308.4499999999998 412.04999999999995
